# %% [markdown]
# ##Q1. Explain the difference between simple linear regression and multiple linear regression. Provide an example of each.
# ![Screenshot 2024-03-19 171825.png](data:image/png;base64,...)![Screenshot 2024-03-19 171844.png](data:image/png;base64,...)

# %% [markdown]
# ##Q2. Discuss the assumptions of linear regression. How can you check whether these assumptions hold in a given dataset?
# Linearity: The relationship between the independent variables and the dependent variable should be linear. This means that the change in the dependent variable is proportional to the change in the independent variables.
#
# Independence of errors: The errors (residuals) should be independent of each other. In other words, there should be no systematic pattern in the residuals. This assumption is crucial for the reliability of statistical inferences.
#
# Homoscedasticity (Constant Variance of Errors): The variance of the errors should be constant across all levels of the independent variables. This means that the spread of the residuals should remain consistent as the values of the independent variables change. If there is a systematic change in the spread of residuals, it indicates heteroscedasticity.
#
# Normality of residuals: The residuals should be normally distributed. This means that the distribution of the residuals should resemble a bell curve when plotted.
#
# No or Little Multicollinearity: There should be little or no multicollinearity among the independent variables. Multicollinearity occurs when independent variables are highly correlated with each other, which can lead to unstable estimates of the regression coefficients.
#
# To check whether these assumptions hold in a given dataset, you can perform various diagnostic tests and visual inspections:
#
# Residual Analysis: Plot the residuals against the predicted values or the independent variables. Look for patterns in the residuals, such as non-linearity or heteroscedasticity.
#
# Normality Tests: Use statistical tests such as the Shapiro-Wilk test, Kolmogorov-Smirnov test, or graphical methods like Q-Q plots to check the normality of residuals.
#
# Homoscedasticity Tests: Perform tests such as the Breusch-Pagan test, White test, or Goldfeld-Quandt test to detect heteroscedasticity. You can also visually inspect plots of residuals against predicted values or independent variables for patterns of changing spread.
#
# Multicollinearity Detection: Calculate the variance inflation factor (VIF) or condition number for each independent variable to assess multicollinearity. Alternatively, you can use techniques like principal component analysis (PCA) or correlation matrices to identify highly correlated variables.
#
# Durbin-Watson Test: This test checks for autocorrelation in the residuals, which violates the assumption of independence of errors. A value of 2 indicates no autocorrelation, while values significantly different from 2 indicate the presence of autocorrelation.
#
# Cook's Distance: This diagnostic measures the influence of each observation on the regression coefficients. High values indicate influential data points that may need further investigation.

# %% [markdown]
# ##Q3. How do you interpret the slope and intercept in a linear regression model? Provide an example using a real-world scenario.
# Y=β
# 0
# ​
#  +β
# 1
# ​
#  X+ε
#
# Y represents the dependent variable.
# X represents the independent variable.
# 0
# β
# 0
# ​
#   is the intercept term.
# 1
# β
# 1
# ​
#   is the slope coefficient.
# ε represents the error term.
#
# Intercept (
#
# 0
# β
# 0
# ​
#  ): The intercept represents the value of the dependent variable when the independent variable is zero. It indicates the starting point of the regression line on the y-axis. In some cases, the intercept may not have a meaningful interpretation, especially if the independent variable cannot realistically take a value of zero. For example, if we're predicting house prices based on square footage, an intercept of $50,000 might indicate the base price for a property with no square footage, which is nonsensical.
#
# Slope (
#
# 1
# β
# 1
# ​
#  ): The slope coefficient represents the change in the dependent variable for a one-unit change in the independent variable. It indicates the steepness or slope of the regression line. A positive slope indicates a positive relationship between the independent and dependent variables, meaning that as the independent variable increases, the dependent variable also increases. A negative slope indicates an inverse relationship, where an increase in the independent variable leads to a decrease in the dependent variable.
#
# Example:
#
# Let's consider a real-world scenario where we want to predict a student's final exam score (dependent variable) based on the number of hours they studied (independent variable). We conduct a linear regression analysis and obtain the following model:
#
# Exam Score
# =
# 60
# +
# 5
# ×
# Hours Studied
# Exam Score=60+5×Hours Studied
#
# Intercept (
#
# 0
# β
# 0
# ​
#  ): In this context, the intercept of 60 indicates the expected exam score for a student who studied zero hours. It represents a baseline score that a student might achieve even without studying. However, this might not be practically meaningful because it's unlikely for a student to score 60 without studying.
#
# Slope (
#
# 1
# β
# 1
# ​
#  ): The slope coefficient of 5 indicates that, on average, for each additional hour studied, a student's exam score is expected to increase by 5 points. This suggests a positive relationship between the number of hours studied and the exam score. In other words, more study time is associated with higher exam scores.

# %% [markdown]
# ##Q4. Explain the concept of gradient descent. How is it used in machine learning?
#
# Gradient descent is an optimization algorithm used to minimize the cost function (or loss function) of a machine learning model by iteratively adjusting the model's parameters. It's a fundamental technique employed in training various types of machine learning models, especially in those where the cost function is differentiable with respect to the model parameters.
#
# Here's how gradient descent works:
#
# Initialization: The process begins by initializing the model parameters with some arbitrary values.
#
# Compute the Gradient: At each iteration, the algorithm computes the gradient of the cost function with respect to each parameter. The gradient represents the direction of steepest ascent of the cost function. In other words, it indicates the direction in which the cost function increases the most.
#
# Update Parameters: The parameters are then updated by taking a small step (determined by a parameter called the learning rate) in the opposite direction of the gradient. This step is what minimizes the cost function. By moving in the direction opposite to the gradient, the algorithm aims to reach the minimum of the cost function.
#
# Repeat: Steps 2 and 3 are repeated iteratively until a stopping criterion is met, such as a maximum number of iterations or when the improvement in the cost function is below a certain threshold.
#
# There are different variants of gradient descent, including:
#
# Batch Gradient Descent: In this variant, the gradient is computed using the entire training dataset. It's computationally expensive for large datasets but guarantees convergence to the global minimum (assuming the cost function is convex).
#
# Stochastic Gradient Descent (SGD): SGD updates the parameters using only one randomly chosen data point (or a small subset, known as a mini-batch) at each iteration. It's computationally efficient and can handle large datasets but may exhibit more noise in the parameter updates.
#
# Mini-batch Gradient Descent: This variant updates the parameters using a small random subset of the training data at each iteration. It combines the advantages of both batch gradient descent and SGD.

# %% [markdown]
# ##Q5. Describe the multiple linear regression model. How does it differ from simple linear regression?
#
# Y is the dependent variable (the variable we want to predict).
#
# 1
# ,
#
# 2
# ,
# .
# .
# .
# ,
#
# X
# 1
# ​
#  ,X
# 2
# ​
#  ,...,X
# p
# ​
#   are the independent variables (predictor variables).
#
# 0
# β
# 0
# ​
#   is the intercept term.
#
# 1
# ,
#
# 2
# ,
# .
# .
# .
# ,
#
# β
# 1
# ​
#  ,β
# 2
# ​
#  ,...,β
# p
# ​
#   are the coefficients of the independent variables, representing the effect of each independent variable on the dependent variable while holding other variables constant.
#
# ε is the error term, representing the unexplained variability in the dependent variable.
# In multiple linear regression, the goal is to estimate the coefficients
#
# 0
# ,
# 1
# ,
# .
# .
# .
# ,
#
# β
# 0
# ​
#  ,β
# 1
# ​
#  ,...,β
# p
# ​
#   that minimize the difference between the observed values of the dependent variable and the values predicted by the model.
#
# Differences between multiple linear regression and simple linear regression:
#
# Number of Independent Variables: In simple linear regression, there is only one independent variable, whereas in multiple linear regression, there are two or more independent variables.
#
# Complexity of the Model: Multiple linear regression allows for a more complex model that can capture the relationships between the dependent variable and multiple independent variables simultaneously. This makes it more flexible in capturing real-world relationships that may involve multiple predictors.
#
# Interpretation of Coefficients: In simple linear regression, the coefficient represents the change in the dependent variable for a one-unit change in the independent variable. In multiple linear regression, the interpretation of coefficients becomes more nuanced as they represent the change in the dependent variable for a one-unit change in the corresponding independent variable while holding other variables constant (assuming no multicollinearity).
#
# Assumptions: The assumptions of multiple linear regression are similar to those of simple linear regression but are extended to account for multiple independent variables. These assumptions include linearity, independence of errors, homoscedasticity, and normality of residuals.

# %% [markdown]
# ##Q6. Explain the concept of multicollinearity in multiple linear regression. How can you detect and address this issue?
# Concept of Multicollinearity:
# High Correlation Among Independent Variables: Multicollinearity arises when independent variables in a regression model are highly correlated, meaning that one independent variable can be linearly predicted from the others with a substantial degree of accuracy.
#
# Effects on Regression Coefficients: When multicollinearity is present, it becomes difficult to determine the true effect of each independent variable on the dependent variable. The estimates of regression coefficients become unstable and can be highly sensitive to small changes in the data.
#
# Detection of Multicollinearity:
# Correlation Matrix: Calculate the correlation coefficients between pairs of independent variables. Correlation values close to +1 or -1 indicate strong linear relationships.
#
# Variance Inflation Factor (VIF): Calculate the VIF for each independent variable. VIF measures how much the variance of an estimated regression coefficient increases if your predictors are correlated. A VIF greater than 10 or 5 is often considered indicative of multicollinearity.
#
# Eigenvalues: Calculate the eigenvalues of the correlation matrix. Multicollinearity is present if one or more eigenvalues are close to zero.
#
# Addressing Multicollinearity:
# Variable Selection: Remove one or more correlated variables from the model. Choose the most relevant variables based on domain knowledge or feature importance techniques.
#
# Combining Variables: Sometimes, it's possible to combine highly correlated variables into a single composite variable. For example, instead of including both height and weight separately, you could include a Body Mass Index (BMI) variable.
#
# Regularization Techniques: Use regularization methods like Ridge Regression or Lasso Regression, which penalize large regression coefficients, thereby reducing the impact of multicollinearity.
#
# Principal Component Analysis (PCA): Transform the original variables into a smaller set of uncorrelated variables (principal components) and use these components as predictors in the regression model.
#
# Data Collection: Collect more data to reduce the correlation between variables. Increasing the sample size can sometimes mitigate multicollinearity issues.

# %% [markdown]
# ##Q7. Describe the polynomial regression model. How is it different from linear regression?
#
# Polynomial Regression Model:
# The polynomial regression model is represented as:
#
# Y=β
# 0
# ​
#  +β
# 1
# ​
#  X+β
# 2
# ​
#  X
# 2
#  +…+β
# n
# ​
#  X
# n
#  +ε
#
#
# Y represents the dependent variable.
#
# X represents the independent variable.
#
# n is the degree of the polynomial.
#
# 0
# ,
#
# 1
# ,
#
# 2
# ,
# …
# ,
#
# β
# 0
# ​
#  ,β
# 1
# ​
#  ,β
# 2
# ​
#  ,…,β
# n
# ​
#   are the coefficients of the polynomial terms.
#
# ε represents the error term.
# The model includes polynomial terms up to the
#
# n-th degree, allowing for nonlinear relationships between
#
# X and
#
# Y. The higher the degree of the polynomial, the more flexible the model becomes in capturing complex patterns in the data. However, higher-degree polynomials can also lead to overfitting, where the model learns the noise in the data rather than the underlying trend.
#
# Differences from Linear Regression:
# Functional Form: In linear regression, the relationship between the variables is modeled as a straight line, whereas in polynomial regression, the relationship can take on a curved shape determined by the degree of the polynomial.
#
# Flexibility: Polynomial regression is more flexible than linear regression because it can capture nonlinear relationships between the variables. It can fit a wider range of data patterns, including quadratic, cubic, or higher-order relationships.
#
# Complexity: With the increased flexibility comes increased complexity. Higher-degree polynomial models can become more complex and prone to overfitting, especially with limited data. Regularization techniques may be necessary to mitigate overfitting.
#
# Interpretability: Linear regression coefficients represent the change in the dependent variable for a one-unit change in the independent variable. In polynomial regression, the interpretation of coefficients becomes more complex as higher-degree polynomial terms are included.

# %% [markdown]
# ##Q8. What are the advantages and disadvantages of polynomial regression compared to linear regression? In what situations would you prefer to use polynomial regression?
#
# dvantages of Polynomial Regression:
#
# Flexibility: Polynomial regression can capture more complex relationships between the independent and dependent variables compared to linear regression. It can fit curved or non-linear patterns in the data.
#
# Better Fit: By incorporating higher-order terms, polynomial regression can often provide a better fit to the data, leading to higher accuracy in predicting the dependent variable.
#
# No Linear Assumption: Unlike linear regression, polynomial regression does not assume a linear relationship between the independent and dependent variables, making it suitable for situations where the true relationship is non-linear.
#
# Disadvantages of Polynomial Regression:
#
# Overfitting: Polynomial regression runs the risk of overfitting the training data, especially when using higher-degree polynomials. Overfitting occurs when the model learns noise in the training data rather than the underlying true relationship, leading to poor performance on unseen data.
#
# Increased Complexity: As the degree of the polynomial increases, the complexity of the model also increases. This can make the model more difficult to interpret and may require more computational resources for training.
#
# Extrapolation Issues: Polynomial regression can be unreliable for extrapolation beyond the range of the observed data. Extrapolating with high-degree polynomials can lead to exaggerated predictions and poor generalization to new data.
#
# When to Use Polynomial Regression:
#
# Non-linear Relationships: When the relationship between the independent and dependent variables is non-linear, polynomial regression may be preferred over linear regression.
#
# Complex Patterns: In situations where the true relationship between variables exhibits complex patterns or curvature, polynomial regression can provide a more accurate representation of the data.
#
# Feature Engineering: Polynomial regression can also be useful as a feature engineering technique to capture non-linear effects of variables in linear models.
#
# In summary, while polynomial regression offers greater flexibility in modeling non-linear relationships compared to linear regression, it also comes with the risk of overfitting and increased complexity. It should be used judiciously, considering the trade-offs between model complexity and predictive performance.
