# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
df = pd.read_excel('/content/drive/MyDrive/flight_price.xlsx')
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# Examine the dimensions
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 10683
# Number of columns: 11

# %% [markdown]
# ##Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(df['Price'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Flight Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ##Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
price_range = df['Price'].max() - df['Price'].min()

# %%
min_price = df["Price"].min()
max_price = df["Price"].max()

# %%
print("Range of prices:", price_range)
print("Minimum Price:",min_price)
print("Maximum price:", max_price)
# Out:
# Range of prices: 77753
# Minimum Price: 1759
# Maximum price: 79512

# %% [markdown]
# ##Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="Airline", y="Price", data=df)
plt.title('Price Variation by Airline')
plt.xlabel('Airline')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Price',data=df)
plt.title('Boxplot of Flight Prices')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# ##Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?
#
# Time Period: Analyzing flight prices over different months or seasons can reveal patterns in demand and pricing fluctuations. This can help identify when travel is most popular and prices are typically higher.
#
# Number of Bookings: Tracking the number of flight bookings over time can indicate peak travel periods when demand is highest.
#
# Historical Data: Examining historical flight price data from previous years can provide insights into recurring peak seasons or events that drive increased travel.
#
# Holiday and Event Calendar: Considering holidays, festivals, and major events in different regions can help identify periods of increased travel activity and higher prices.
#
# Destination Trends: Analyzing popular destinations and their seasonal patterns can also contribute to identifying peak travel seasons.

# %% [markdown]
# ##Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?
#
#
# ime Series Analysis: Examining how flight prices change over time can reveal long-term trends, seasonal patterns, and short-term fluctuations.
#
# Route Analysis: Analyzing price trends for specific routes can help identify differences in pricing strategies and demand between different destinations.
#
# Day of the Week: Studying how flight prices vary depending on the day of the week can uncover trends related to weekday versus weekend travel.
#
# Time of Booking: Investigating whether there are any patterns in price fluctuations based on the time of booking (e.g., early booking discounts, last-minute deals).
#
# Flight Duration: Exploring how flight prices correlate with the duration of the flight can provide insights into pricing strategies based on convenience or efficiency.
#
# Seasonal Variations: Identifying how flight prices change with the seasons can highlight peak travel periods and off-peak seasons.
#
#
# To present my findings to the team, I would use various visualizations tailored to each feature analyzed:
#
# Time Series Plots: Line graphs showing the trend of flight prices over time, with different lines representing different routes or categories of flights.
#
# Route Maps: Geospatial visualizations depicting average flight prices for different routes on a map, allowing the team to quickly identify patterns and variations across regions.
#
# Bar Charts or Box Plots: Displaying average flight prices by day of the week, with bars or boxes representing the range of prices and any outliers.
#
# Scatter Plots: Plotting flight prices against the time of booking to visualize any correlations or trends, with color coding to differentiate between different booking times.
#
# Seasonal Decomposition Plots: Decomposing time series data into its seasonal, trend, and residual components to illustrate seasonal variations in flight prices.

# %% [markdown]
# ##Q8. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?
#
# Departure and Arrival Locations: Analyzing how flight prices vary based on departure and arrival locations can help identify regional pricing differences and demand patterns.
#
# Time of Booking: Studying the relationship between the time of booking and flight prices can reveal trends such as early booking discounts or last-minute deals.
#
# Flight Duration: Investigating how flight prices are affected by the duration of the flight can indicate pricing strategies based on convenience or efficiency.
#
# Seasonality: Analyzing how flight prices fluctuate with the seasons can highlight peak travel periods and off-peak seasons, which may affect pricing strategies.
#
# Day of the Week: Examining how flight prices vary depending on the day of the week can uncover pricing strategies related to weekday versus weekend travel.
#
# Airline Carrier: Investigating differences in flight prices between different airlines can reveal competitive pricing strategies and brand positioning.
#
# Flight Class: Analyzing price variations between different classes (e.g., economy, business, first class) can indicate pricing strategies based on customer segmentation.
#
# Special Events and Holidays: Considering the impact of special events, holidays, and festivals on flight prices can help identify pricing adjustments related to increased demand during these periods.
#
#
#
# Descriptive Statistics: Presenting summary statistics for each feature analyzed, such as average prices, standard deviations, and ranges, to provide a clear overview of the dataset.
#
# Visualization: Using various types of visualizations such as bar charts, line graphs, scatter plots, and heatmaps to illustrate the relationships between different factors and flight prices.
#
# Regression Analysis: Conducting regression analysis to quantify the impact of each factor on flight prices and identify significant predictors.
#
# Key Insights: Summarizing key findings and insights derived from the analysis, including actionable recommendations for pricing strategies, revenue optimization, and market positioning.
#
# Interactive Dashboards: Creating interactive dashboards that allow management to explore the data dynamically and drill down into specific factors or segments affecting flight prices.

# %% [markdown]
# ##Google Playstore:

# %% [markdown]
# ##Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv ("/content/googleplaystore.csv")

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
print("number of rows", df1.shape[0])
print("number of colums", df1.shape[1])
# Out:
# number of rows 10841
# number of colums 13

# %% [markdown]
# ##Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Content Rating', y="Category", data=df1)
plt.title("Rating")
plt.xlabel("Categories")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.

# %%
missing_values = df1.isnull().sum()
print(missing_values)
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# Imputation: If there are only a few missing values in certain columns, I might consider imputing these missing values using methods such as mean, median, or mode imputation. However, this could introduce bias or inaccuracies in the analysis if the missing values are not missing at random.
#
# Removal: If the missing values are substantial or cannot be reasonably imputed, I might choose to remove the rows or columns containing missing values from the analysis. However, this could lead to a loss of valuable data and potentially bias the results if there is a systematic reason for the missing values.
#
# Impact on Analysis: Missing values can impact the statistical validity and reliability of the analysis, potentially leading to biased estimates, reduced statistical power, or erroneous conclusions. Therefore, it's essential to carefully handle missing values through appropriate imputation or removal strategies to ensure the integrity of the analysis results.

# %% [markdown]
# ##Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Size', y='Rating', data=df1)

plt.title('Relationship between App Size and Rating')
plt.xlabel('Size of shap the App')
plt.ylabel("Rating")
plt.show()

# %% [markdown]
# ##Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
plt.figure(figsize=(10, 6))
plt.bar(df1['Category'],df1['Price'],color='skyblue')
plt.title('Average Price by app category')
plt.xlabel('App Category')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# ##Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159   19M     10000  Free     0       Everyone
# 1     967   14M    500000  Free     0       Everyone
# 2   87510  8.7M   5000000  Free     0       Everyone
# 3  215644   25M  50000000  Free     0           Teen
# 4     967  2.8M    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df1["Installs"] = df1["Installs"].astype(str)
df1["Installs"] = df1["Installs"].str.replace('+','').str.replace(',', '')

app_installs_freq = df1.groupby('App')['Installs'].sum().reset_index()
top_10_apps = app_installs_freq.sort_values(by='Installs', ascending=False).head(10)


print('Top 10 Most Popuplar Apps:')
print(top_10_apps)
# Out:
# Top 10 Most Popuplar Apps:
#                                           App      Installs
# 6917               Penn State Health OnDemand          5050
# 2397   Cardi B Live Stream Video Chat - Prank        500500
# 5443                JH Blood Pressure Monitor        500500
# 4614                      Free Blood Pressure  500050005000
# 6668                                   O-Star  500050005000
# 5272                                    Howlr      50005000
# 5850        Live Girls Talk - Free Video Chat      50005000
# 6027            Manga AZ - Manga Comic Reader      50005000
# 6113  Medical ID - In Case of Emergency (ICE)      50005000
# 710                               AnatomyMapp      50005000
# <ipython-input-41-9670c32bf80d>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %% [markdown]
# ##Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?
#
#
# Data Collection: Obtain the Google Play Store dataset containing information about various apps, including their categories, ratings, reviews, and installs.
#
# Data Cleaning and Preparation: Preprocess the dataset to handle missing values, remove duplicates, and ensure consistency in data types. Additionally, filter out any irrelevant columns that are not required for the analysis.
#
# Exploratory Data Analysis (EDA): Conduct exploratory data analysis to gain insights into the dataset. Analyze summary statistics, distributions, and correlations between different features.
#
# Analysis of App Categories: Focus on the 'Category' column to analyze the distribution of apps across different categories. Calculate the total number of apps, average ratings, and total installs for each category.
#
# Identify Popular Categories: Determine the most popular app categories based on criteria such as the highest number of installs, highest average ratings, or a combination of both. This can be achieved by ranking the categories based on relevant metrics.
#
# Visualization and Presentation: Visualize the findings using appropriate charts and graphs such as bar charts, pie charts, or histograms. Present the results to the company in a clear and understandable format, highlighting the most popular app categories and supporting insights.
#
# Recommendations: Based on the analysis, provide recommendations to the company regarding the most promising app categories to target for their new app launch. Consider factors such as competition, market demand, and potential for growth within each category.
#
# Features to analyze to make recommendations to the company include:
#
# Category: The primary feature to analyze, as it represents the genre or type of app.
# Installs: To determine the popularity and demand for apps within each category.
# Ratings: To assess the quality and user satisfaction of apps within each category.
# Reviews: To gain insights into user feedback and engagement for apps within each category.
# Size: To understand the distribution of app sizes within each category, which may influence user preferences.
# Price: To examine pricing strategies and monetization opportunities within each category.

# %% [markdown]
# ##Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the most successful app developers. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?
#
# umber of Apps: Analyze the total number of apps published by each developer. Developers with a higher number of apps might indicate experience and expertise in app development.
#
# Data Visualization: Use a bar chart or histogram to visualize the distribution of the number of apps published by each developer.
# Average Ratings: Examine the average ratings of apps published by each developer. Higher average ratings suggest better quality and user satisfaction.
#
# Data Visualization: Create a box plot or violin plot to compare the distribution of average ratings across different developers.
# Total Installs: Evaluate the total number of installs for all apps published by each developer. Higher total installs indicate popularity and success.
#
# Data Visualization: Use a bar chart or scatter plot to visualize the total installs for each developer.
# Average Installs per App: Calculate the average number of installs per app for each developer. This metric accounts for the success of individual apps published by developers.
#
# Data Visualization: Create a histogram or box plot to visualize the distribution of average installs per app for each developer.
# User Reviews: Analyze the total number of user reviews and the sentiment of reviews (positive, negative, neutral) for apps published by each developer. Positive reviews indicate user satisfaction and engagement.
#
# Data Visualization: Use a stacked bar chart or grouped bar chart to visualize the distribution of positive, negative, and neutral reviews for each developer.
# App Size and Price: Consider the average size and price of apps published by each developer. Smaller app sizes and reasonable prices may attract more users.
#
# Data Visualization: Create a scatter plot or box plot to compare the average size and price of apps across different developers.
# Retention Rate: Calculate the retention rate or churn rate of users for apps published by each developer. Higher retention rates indicate app stickiness and user engagement.
#
# Data Visualization: Use a line graph or area chart to visualize the retention rate over time for apps published by each developer.

# %% [markdown]
# ##Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to launch a new app. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?
#
# App Release Date: Analyze the distribution of app release dates to identify trends and patterns in app launches over time. This can help determine if there are specific months or seasons when app launches are more common or successful.
#
# Data Visualization: Use a line graph or histogram to visualize the number of app releases over time, grouped by month or year.
# Average Ratings Over Time: Examine how app ratings change over time after their initial release. This can indicate the long-term success and user satisfaction of apps launched at different times.
#
# Data Visualization: Create a line graph or scatter plot to visualize the average ratings of apps over time since their release date.
# Total Installs Over Time: Analyze the trend of total app installs over time to understand user adoption and demand patterns. This can help identify periods of high user engagement and market saturation.
#
# Data Visualization: Use a line graph or area chart to visualize the total installs of apps over time, grouped by month or year.
# Competition Analysis: Evaluate the number of new app releases and the performance of existing apps in the same category as the new app. Understanding the competitive landscape can help determine the optimal timing for launching a new app.
#
# Data Visualization: Create a grouped bar chart or stacked area chart to compare the number of new app releases and the average ratings of existing apps in the same category over time.
# Seasonal Trends: Explore seasonal trends and events that may impact app launches and user behavior. For example, holidays, festivals, or industry events may influence app downloads and user engagement.
#
# Data Visualization: Use a line graph or heatmap to visualize the seasonal variation in app launches, installs, or user engagement metrics.
# User Reviews: Analyze user reviews and sentiment to understand how user perception of apps changes over time. This can provide insights into user satisfaction and app performance.
#
# Data Visualization: Create a stacked bar chart or scatter plot to visualize the distribution of positive, negative, and neutral reviews over time since app release.
# App Update Frequency: Consider the frequency of app updates and how it impacts app performance and user engagement. Apps that receive regular updates may have higher user retention and satisfaction.
#
# Data Visualization: Use a line graph or bar chart to visualize the frequency of app updates over time and its correlation with app ratings or installs.
